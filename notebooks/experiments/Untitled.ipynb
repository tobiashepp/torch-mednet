# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Input

# %%
img = nib.load('/home/raheppt1/IXI_test.nii.gz')
print(f'input orientation {nib.aff2axcodes(img.affine)}, shape {img.header.get_data_shape()}')
plt.imshow(img.get_fdata(dtype=np.float32)[:,:,100])
# Out:
# input orientation ('P', 'S', 'R'), shape (256, 256, 150)

# %% [markdown]
# ### Reorientation

# %%
img = nib.load('/home/raheppt1/tmp/fslreorient/IXI_test.nii.gz')
print(f'input orientation {nib.aff2axcodes(img.affine)}, shape {img.header.get_data_shape()}')
plt.imshow(img.get_fdata(dtype=np.float32)[:,120,:])
# Out:
# input orientation ('L', 'A', 'S'), shape (150, 256, 256)

# %% [markdown]
# ### Robust FOV

# %%
img = nib.load('/home/raheppt1/tmp/robustfov/IXI_test.nii.gz')
print(f'input orientation {nib.aff2axcodes(img.affine)}, shape {img.header.get_data_shape()}')
plt.imshow(img.get_fdata(dtype=np.float32)[:,120,:])
# Out:
# input orientation ('L', 'A', 'S'), shape (150, 256, 256)

# %% [markdown]
# ### N4BiasFieldCorrection

# %%
img = nib.load('/home/raheppt1/tmp/N4BiasFieldCorrection/IXI_test.nii.gz')
print(f'input orientation {nib.aff2axcodes(img.affine)}, shape {img.header.get_data_shape()}')
plt.imshow(img.get_fdata(dtype=np.float32)[:,120,:])
# Out:
# input orientation ('L', 'A', 'S'), shape (150, 256, 256)

# %%
img = nib.load('/home/raheppt1/FSL/data/standard/MNI152_T1_1mm.nii.gz')
print(f'input orientation {nib.aff2axcodes(img.affine)}, shape {img.header.get_data_shape()}')
plt.imshow(img.get_fdata(dtype=np.float32)[:,120,:])
# Out:
# input orientation ('L', 'A', 'S'), shape (182, 218, 182)

# %%
img = nib.load('/home/raheppt1/tmp/MNIRegistration/IXI_test.nii.gz')
print(f'input orientation {nib.aff2axcodes(img.affine)}, shape {img.header.get_data_shape()}')
plt.imshow(img.get_fdata(dtype=np.float32)[:,120,:])
# Out:
# input orientation ('L', 'A', 'S'), shape (182, 218, 182)

# %%
img = nib.load('/home/raheppt1/out/IXI_test.nii.gz')
print(f'input orientation {nib.aff2axcodes(img.affine)}, shape {img.header.get_data_shape()}')
plt.imshow(img.get_fdata(dtype=np.float32)[:,120,:])
# Out:
# input orientation ('L', 'A', 'S'), shape (182, 218, 182)
